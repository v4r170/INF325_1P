# %% [markdown]
# # Preprocesamiento en Python

# %%
import numpy as np
from scipy import stats

import pandas as pd 
df = pd.read_csv("feminicidio2020.csv")

pd.set_option('display.max_rows',None)
#df.head()
print(df)
# Out:
#     departamento    area                 relacion hijos  \
# 0          Oruro  Urbana                  Conyuge    Si
# 1     Cochabamba  Urbana  Otra pareja sentimental    No
# 2     Cochabamba  Urbana           Ex conviviente    No
# 3     Cochabamba  Urbana                  Conyuge    Si
# 4     Cochabamba  Urbana              Conviviente    No
# 5     Cochabamba  Urbana              Desconocido   NaN
# 6     Cochabamba  Urbana              Desconocido    No
# 7         La Paz  Urbana  Otra pareja sentimental    No
# 8         La Paz  Urbana                 Familiar    No
# 9         La Paz  Urbana  Otra pareja sentimental    No
# 10    Cochabamba  Urbana            Otra relacion    No
# 11        La Paz  Urbana                 Familiar    No
# 12    Cochabamba  Urbana              Conviviente    No
# 13    Cochabamba  Urbana                  Conyuge    No
# 14        La Paz  Urbana                  Conyuge    Si
# 15        La Paz  Urbana              Conviviente    Si
# ...

# %% [markdown]
# IMPUTACION El dataset tiene campos vacios, como los datos son cualitativos, se procede a calcular la moda

# %%
moda=stats.mode(df)
print(moda)
print(moda[0][0])
m=moda[0][0];
# Out:
# ModeResult(mode=array([['La Paz', 'Urbana', 'Conyuge', 'No', '27 a 59 (adulta)',
#         '27 a 59 (adulto)', 'Domicilio compartido', 'Golpe/traumatismo']],
#       dtype=object), count=array([[ 62, 155,  48, 105,  92,  94,  59,  57]]))
# ['La Paz' 'Urbana' 'Conyuge' 'No' '27 a 59 (adulta)' '27 a 59 (adulto)'
#  'Domicilio compartido' 'Golpe/traumatismo']

# %%
data1=df.to_numpy()
print(data1)

c=data1[:,1]
print(c)
c=c[c>'']
print(c)
mm=m[1];
print("moda=",mm)
for i in range(0,5):
    if(data1[i][1]==''):
       data1[i][1]=mm
print(data1)
# Out:
# [['Oruro' 'Urbana' 'Conyuge' ... '27 a 59 (adulto)'
#   'Domicilio compartido' 'Golpe/traumatismo']
#  ['Cochabamba' 'Urbana' 'Otra pareja sentimental' ... '18 a 26 (joven)'
#   'Domicilio de la victima' 'Estrangulamiento']
#  ['Cochabamba' 'Urbana' 'Ex conviviente' ... '18 a 26 (joven)'
#   'Lugar de trabajo' 'Arma de fuego']
#  ...
#  ['Beni' 'Urbana' 'Conviviente' ... nan 'Domicilio compartido'
#   'Golpe/traumatismo']
#  ['Beni' 'Urbana' 'Conviviente' ... nan 'Domicilio compartido'
#   'Arma Blanca']
#  ['Beni' 'Urbana' 'Conyuge' ... nan 'Domicilio compartido'
#   'Estrangulamiento']]
# ['Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana'
#  'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana'
#  'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana'
#  'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana' 'Urbana'
#  'Urbana' 'La Paz' 'Rural' 'Urbana' 'Rural' 'Rural' 'Urbana' 'Urbana'
# ...

# %%
print(m[1])
for j in range(0,172):
    if not (df1["area"][j]):
        print(df["area"][j])
    else:
        print("Nulo",df["area"][j])
        df["area"][j]=m[1]
    
            
print(df)
# Out:
# La Paz
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Nulo nan
# Rural
# Urbana
# Rural
# Rural
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Rural
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Rural
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Rural
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Nulo nan
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Urbana
# Rural
# Urbana
# Urbana
# Urbana
# ...
